# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime, timedelta
from dateutil.relativedelta import relativedelta

# %%
df = pd.read_csv('sample_data.csv', parse_dates=['timestamp'])
df.head(2)
# Out:
#             account_id                ad_id event_name  \
# 0   249683985899310273  -159265360436186278      order
# 1  2753457128963724056 -6487219347028929285      order
#
#                    timestamp   platform category_name  region_name  \
# 0 2018-05-16 17:33:18.350333  on_behalf          Cars  Đông Bắc Bộ
# 1 2018-05-04 16:03:08.099983  on_behalf          Cars  Đông Bắc Bộ
#
#   condition_ad_name        price
# 0               Mới  267000000.0
# 1               Mới  399000000.0

# %%
df.timestamp.dt.year.unique()
# Out:
# array([2018], dtype=int64)

# %%
df.timestamp.dt.month.unique()
# Out:
# array([ 5,  4,  1, 11,  7,  6, 10,  9,  8, 12,  2,  3], dtype=int64)

# %% [markdown]
# ktra các thời gian có lờn hơn ko

# %%
df.timestamp.iloc[0] > df.timestamp.iloc[1]
# Out:
# True

# %%
df.timestamp.iloc[0] + relativedelta.relativedelta(days=30)
# Out:
# Timestamp('2018-06-15 17:33:18.350333')

# %%
sort ngày tháng

# %%
df.sort_values(by=['timestamp'], inplace=True)

# %%
df.shift(-1).head(5)
# Out:
#            account_id         ad_id event_name                  timestamp  \
# 2994532 -8.407426e+18  8.073062e+18     insert 2018-01-01 00:00:36.931802
# 4645236 -7.568758e+18 -5.263995e+18     insert 2018-01-01 00:00:40.496153
# 1159697  3.676150e+18 -7.324368e+18     insert 2018-01-01 00:01:04.648987
# 4228723 -1.714248e+18 -7.031000e+18     insert 2018-01-01 00:01:47.442225
# 3285600  5.552368e+18 -5.388909e+18     insert 2018-01-01 00:02:04.452890
#
#         platform      category_name                   region_name  \
# 2994532  unknown              Watch  Hải Phòng Nam Định Thái Bình
# 4645236  unknown  Other accessories                        Hà Nội
# 1159697  unknown      Mobile Phones             Quảng Nam Đà Nẵng
# 4228723  unknown         PTY-Houses                Tp Hồ Chí Minh
# 3285600  unknown          PTY-Rooms                Tp Hồ Chí Minh
#
#         condition_ad_name         price
# 2994532        Đã sử dụng  4.000000e+05
# 4645236        Đã sử dụng  3.800000e+06
# ...

# %%
df.head(5)
# Out:
#                   account_id                ad_id event_name  \
# 2994532 -5185263014238151372  9007088381742310786     insert
# 4645236 -8407426375339280932  8073061906814887495     insert
# 1159697 -7568757835475363824 -5263995320096697334     insert
# 4228723  3676149832513067244 -7324368144102749630     insert
# 3285600 -1714247614107389390 -7031000381247332750     insert
#
#                          timestamp platform      category_name  \
# 2994532 2018-01-01 00:00:31.351277  unknown         PTY-Houses
# 4645236 2018-01-01 00:00:36.931802  unknown              Watch
# 1159697 2018-01-01 00:00:40.496153  unknown  Other accessories
# 4228723 2018-01-01 00:01:04.648987  unknown      Mobile Phones
# 3285600 2018-01-01 00:01:47.442225  unknown         PTY-Houses
#
#                           region_name condition_ad_name         price
# 2994532                Tp Hồ Chí Minh               NaN  3.650000e+08
# 4645236  Hải Phòng Nam Định Thái Bình        Đã sử dụng  4.000000e+05
# ...

# %%
df.sort_values(by=['account_id', 'timestamp'], ascending=[True, False], inplace=True)

# %%
df_shift = df.shift(-1)

# %%
df
# Out:
#                   account_id                ad_id event_name  \
# 1406849 -9223336493830730905  3088179676471213070     insert
# 1343878 -9223336493830730905 -5279128860130030977     insert
# 1408567 -9223336493830730905 -2462399768676748292     insert
# 2560039 -9223105201273952408  -177089586640378831     insert
# 3168169 -9223105201273952408  3166031885300745638     insert
# ...                      ...                  ...        ...
# 2990030  9222818434278833078  3152323916706631008     insert
# 2008496  9222818434278833078 -2689649165537767256     insert
# 3060637  9222846988747675895 -6943754032404835247     insert
# 1056603  9223034564554224042 -2662422231389708119     insert
# 1077607  9223034564554224042  5650212949988821826     insert
#
#                          timestamp platform           category_name  \
# 1406849 2018-01-21 17:21:35.069056  unknown           Mobile Phones
# 1343878 2018-01-03 17:00:08.497463  unknown                 Tablets
# ...

# %%
account_type = lambda x : x.timestamp - x.timestamp.shift(-1)

# %%
account_type = df.groupby('account_id').apply(account_type)

# %%
days = account_type.to_frame().reset_index()['timestamp'].dt.days

# %%
df['account_type'] = np.where(days > 30, 'new', np.where(days <= 30, 'old', days))

# %%
df

# %%
account_type = lambda x : x.timestamp - x.timestamp.shift(-1)
account_type = df.groupby('account_id').apply(account_type)
days = account_type.to_frame().reset_index()['timestamp'].dt.days
df['account_type'] = np.where(days > 30, 'new', np.where(days <= 30, 'old', days))

# %%
df
# Out:
#                   account_id                ad_id event_name  \
# 1406849 -9223336493830730905  3088179676471213070     insert
# 1343878 -9223336493830730905 -5279128860130030977     insert
# 1408567 -9223336493830730905 -2462399768676748292     insert
# 2560039 -9223105201273952408  -177089586640378831     insert
# 3168169 -9223105201273952408  3166031885300745638     insert
# ...                      ...                  ...        ...
# 2990030  9222818434278833078  3152323916706631008     insert
# 2008496  9222818434278833078 -2689649165537767256     insert
# 3060637  9222846988747675895 -6943754032404835247     insert
# 1056603  9223034564554224042 -2662422231389708119     insert
# 1077607  9223034564554224042  5650212949988821826     insert
#
#                          timestamp platform           category_name  \
# 1406849 2018-01-21 17:21:35.069056  unknown           Mobile Phones
# 1343878 2018-01-03 17:00:08.497463  unknown                 Tablets
# ...

# %%
Tìm vị trí ngày 30 trước đó nhưng bé hơn ngày hiện tại
cc_30_date = account_array[i+1: ][np.argwhere(arr_datetime >=back_30_date)

# %%
arr_account = df.account_id.to_numpy()
arr_datetime = df.timestamp.to_numpy(dtype=pd.timestamp)
for i in arr_count.shape[0]:
    back_30_date = arr_datetime[i] - relativedelta(months=1)
    acc_back_30 = account_array[i+1: ][np.argwhere(arr_datetime >= back_30_date)
                                       if acc_back_30[acc_back_30 == arr_account[i]].shape[0] > 0:
                                       acc_type.append(0)
                                       else:
                                       acc_type.append(1)
# Out:
#   File "<ipython-input-19-96ed39e736fe>", line 6
#     if acc_back_30[acc_back_30 == arr_account[i]].shape[0] > 0:
#                                                               ^
# SyntaxError: invalid syntax

# %%
arr_account = df.account_id.to_numpy()
